# %% [markdown]
# # Import Packages

# %%
# !pip install yfinance   # Install Yahoo Finance library

import yfinance as yf
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn import metrics
from keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Conv1D, MaxPool1D, Dense, Flatten, Dropout
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: yfinance in /usr/local/lib/python3.7/dist-packages (0.1.87)
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from yfinance) (4.9.1)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.4.4)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.21.6)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.7/dist-packages (from yfinance) (2.28.1)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2022.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.1.1)

# %% [markdown]
# # Stock Data Download

# %%
def download(stock):  
    """
    Download the stock historical data.

    Parameters
    ----------
    stock: str
      Stock symbol.

    Returns
    -------
    DataFrame
      Downloaded stock data.
    """

    df = yf.download(
      [stock],
      start="2017-01-01",
      end="2022-01-01",
      group_by="ticker",
      progress=False
    )
    df = df.round(4)

    return df


# Download the five stocks
df_AAPL = download('AAPL')
df_AMZN = download('AMZN')
df_GOOGL = download('GOOGL')
df_META = download('META')
df_MSFT = download('MSFT')

# Set the input feature
aapl_input = df_AAPL['Adj Close'] 
amzn_input = df_AMZN['Adj Close'] 
googl_input = df_GOOGL['Adj Close'] 
meta_input = df_META['Adj Close'] 
msft_input = df_MSFT['Adj Close']

# %% [markdown]
# # Data Normalization

# %%
# Set the scaler to a range between 0 and 1
scaler = MinMaxScaler(feature_range=(0,1))

# Fit the scaler to data, and then transform it
aapl_scaled = scaler.fit_transform(aapl_input.values.reshape(-1,1))
amzn_scaled  = scaler.fit_transform(amzn_input.values.reshape(-1,1))
googl_scaled = scaler.fit_transform(googl_input.values.reshape(-1,1))
meta_scaled = scaler.fit_transform(meta_input.values.reshape(-1,1))
msft_scaled = scaler.fit_transform(msft_input.values.reshape(-1,1))

# %% [markdown]
# # Data Processing & Data Split

# %%
# Process the data to fit the prediction's format: Use previous n days' data to predict the next day data

def data_processing(data , sliding_window_number):
    """
    Process the data 

    Parameters
    ----------
    data: Numpy array
      Training or testing data.
    sliding_window_number: int
      Number of days.

    Returns
    -------
    Numpy array
      Response (X) and predictor (y) variables data of training or testing data.
    """

    # dataX stores the previous n days' data; dataY stores the day (n+1) data
    dataX, dataY = [], []
    for i in range(sliding_window_number,len(data)):  
      # Append the data from (i-sliding window number)th to (i-1)th    
      dataX.append(data[i-sliding_window_number:i,0])   
      # Append the i(th) data
      dataY.append(data[i,0])               

    return np.array(dataX), np.array(dataY)


#----------------------------------------------------------------------------------
# Apple 
# Split data into training & testing dataset  
train_aapl = aapl_scaled[0:880,:]
test_aapl = aapl_scaled[880:,:]

# Process the input data
X_train_aapl, y_train_aapl = data_processing(train_aapl, 10)
X_test_aapl, y_test_aapl = data_processing(test_aapl, 10)

# Reshape to fit the CNN required input shape (number of samples, time steps, features per sample)
X_train_aapl = X_train_aapl.reshape(X_train_aapl.shape[0],X_train_aapl.shape[1],1)
X_test_aapl = X_test_aapl.reshape(X_test_aapl.shape[0],X_test_aapl.shape[1],1)

#----------------------------------------------------------------------------------
# Amazon
train_amzn = amzn_scaled[0:880,:]
test_amzn = amzn_scaled[880:,:]

X_train_amzn, y_train_amzn = data_processing(train_amzn, 10)
X_test_amzn, y_test_amzn = data_processing(test_amzn, 10)

X_train_amzn = X_train_amzn.reshape(X_train_amzn.shape[0],X_train_amzn.shape[1],1)
X_test_amzn = X_test_amzn.reshape(X_test_amzn.shape[0],X_test_amzn.shape[1],1)

#----------------------------------------------------------------------------------
# Google
train_googl = googl_scaled[0:880,:]
test_googl = googl_scaled[880:,:]

X_train_googl, y_train_googl = data_processing(train_googl, 10)
X_test_googl, y_test_googl = data_processing(test_googl, 10)

X_train_googl = X_train_googl.reshape(X_train_googl.shape[0],X_train_googl.shape[1],1)
X_test_googl = X_test_googl.reshape(X_test_googl.shape[0],X_test_googl.shape[1],1)

#----------------------------------------------------------------------------------
# Meta
train_meta = meta_scaled[0:880,:]
test_meta = meta_scaled[880:,:]

X_train_meta, y_train_meta = data_processing(train_meta, 10)
X_test_meta, y_test_meta = data_processing(test_meta, 10)

X_train_meta = X_train_meta.reshape(X_train_meta.shape[0],X_train_meta.shape[1],1)
X_test_meta = X_test_meta.reshape(X_test_meta.shape[0],X_test_meta.shape[1],1)

#----------------------------------------------------------------------------------
# Microsoft
train_msft = msft_scaled[0:880,:]
test_msft = msft_scaled[880:,:]

X_train_msft, y_train_msft = data_processing(train_msft, 10)
X_test_msft, y_test_msft = data_processing(test_msft, 10)

X_train_msft = X_train_msft.reshape(X_train_msft.shape[0],X_train_msft.shape[1],1)
X_test_msft = X_test_msft.reshape(X_test_msft.shape[0],X_test_msft.shape[1],1)

# %% [markdown]
# # Early Stopping

# %%
# Callback - Early Stopping used in CNN model 

earlystopping = EarlyStopping(monitor='val_loss', mode ='min', min_delta=0 ,patience=10, verbose=1)

# %% [markdown]
# # CNN Model Training & Prediction

# %%
# Apply CNN model to five stocks
 
def CNN_model():
    """
    Build the CNN model architecture.

    Parameters
    ----------
    None.

    Returns
    -------
    CNN model architecture.
    """

    model = Sequential()
  
    model.add(Conv1D(filters=128, kernel_size=3, activation='relu', input_shape=(10, 1)))   
    model.add(MaxPool1D(pool_size=2))   
    model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(10, 1))) 
    model.add(MaxPool1D(pool_size=2))
    model.add(Flatten()) 
    model.add(Dropout(0.3))
    model.add(Dense(1))

    model.compile(loss='mean_squared_error', optimizer='adam',metrics=['mean_squared_error'])

    return model


# Model Training
#----------------------------------------------------------------------------------
# Apple
# Instantiate the model 
model_aapl = CNN_model()   
print(model_aapl.summary())
# Fit the model
history_aapl = model_aapl.fit(X_train_aapl, y_train_aapl, batch_size=256, epochs=100, validation_data= (X_test_aapl,y_test_aapl), callbacks=[earlystopping])  
# Predict the results
y_pred_aapl = model_aapl.predict(X_test_aapl)

#----------------------------------------------------------------------------------
# Amazon
model_amzn = CNN_model()   
history_amzn = model_amzn.fit(X_train_amzn, y_train_amzn, batch_size=256, epochs=100, validation_data=(X_test_amzn,y_test_amzn), callbacks=[earlystopping]) 
y_pred_amzn = model_amzn.predict(X_test_amzn)

#----------------------------------------------------------------------------------
# Google
model_googl = CNN_model()
history_googl = model_googl.fit(X_train_googl, y_train_googl, batch_size=256, epochs=100, validation_data=(X_test_googl,y_test_googl), callbacks=[earlystopping]) 
y_pred_googl = model_googl.predict(X_test_googl)

#----------------------------------------------------------------------------------
# Meta
model_meta = CNN_model()
history_meta = model_meta.fit(X_train_meta, y_train_meta, batch_size=256, epochs=100, validation_data=(X_test_meta,y_test_meta), callbacks=[earlystopping]) 
y_pred_meta = model_meta.predict(X_test_meta)

#----------------------------------------------------------------------------------
# Microsoft
model_msft = CNN_model()
history_msft = model_msft.fit(X_train_msft, y_train_msft, batch_size=256, epochs=100, validation_data=(X_test_msft,y_test_msft), callbacks=[earlystopping]) 
y_pred_msft = model_msft.predict(X_test_msft)


# An image description of the model structure 
plot_model(model_aapl, to_file='model_structure.png', show_shapes=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 8, 128)            512
#
#  max_pooling1d (MaxPooling1D  (None, 4, 128)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 2, 64)             24640
#
#  max_pooling1d_1 (MaxPooling  (None, 1, 64)            0
#  1D)
#
#  flatten (Flatten)           (None, 64)                0
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 25,217
# Trainable params: 25,217
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 4/4 [==============================] - 1s 100ms/step - loss: 0.0137 - mean_squared_error: 0.0137 - val_loss: 0.1091 - val_mean_squared_error: 0.1091
# Epoch 2/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0189 - val_mean_squared_error: 0.0189
# Epoch 3/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 4/100
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0158 - val_mean_squared_error: 0.0158
# Epoch 5/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0264 - val_mean_squared_error: 0.0264
# Epoch 6/100
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0135 - val_mean_squared_error: 0.0135
# Epoch 7/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 8/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 9.8123e-04 - val_mean_squared_error: 9.8123e-04
# Epoch 9/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 10/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 11/100
# 4/4 [==============================] - 0s 21ms/step - loss: 9.6458e-04 - mean_squared_error: 9.6458e-04 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 12/100
# 4/4 [==============================] - 0s 30ms/step - loss: 8.7380e-04 - mean_squared_error: 8.7380e-04 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 13/100
# 4/4 [==============================] - 0s 27ms/step - loss: 7.2745e-04 - mean_squared_error: 7.2745e-04 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 14/100
# 4/4 [==============================] - 0s 26ms/step - loss: 7.3493e-04 - mean_squared_error: 7.3493e-04 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 15/100
# 4/4 [==============================] - 0s 26ms/step - loss: 7.6148e-04 - mean_squared_error: 7.6148e-04 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 16/100
# 4/4 [==============================] - 0s 22ms/step - loss: 7.7095e-04 - mean_squared_error: 7.7095e-04 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 17/100
# 4/4 [==============================] - 0s 28ms/step - loss: 7.9436e-04 - mean_squared_error: 7.9436e-04 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 18/100
# 4/4 [==============================] - 0s 40ms/step - loss: 7.5856e-04 - mean_squared_error: 7.5856e-04 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 18: early stopping
# 12/12 [==============================] - 0s 6ms/step
# Epoch 1/100
# 4/4 [==============================] - 2s 135ms/step - loss: 0.0754 - mean_squared_error: 0.0754 - val_loss: 0.2942 - val_mean_squared_error: 0.2942
# Epoch 2/100
# 4/4 [==============================] - 0s 51ms/step - loss: 0.0262 - mean_squared_error: 0.0262 - val_loss: 0.0877 - val_mean_squared_error: 0.0877
# Epoch 3/100
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0101 - val_mean_squared_error: 0.0101
# Epoch 4/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 5/100
# 4/4 [==============================] - 0s 63ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 6/100
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0211 - val_mean_squared_error: 0.0211
# Epoch 7/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0197 - val_mean_squared_error: 0.0197
# Epoch 8/100
# 4/4 [==============================] - 0s 61ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0080 - val_mean_squared_error: 0.0080
# Epoch 9/100
# 4/4 [==============================] - 0s 66ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 10/100
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 11/100
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 12/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 13/100
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 14/100
# 4/4 [==============================] - 0s 86ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 14: early stopping
# 12/12 [==============================] - 0s 4ms/step
# Epoch 1/100
# 4/4 [==============================] - 2s 149ms/step - loss: 0.0155 - mean_squared_error: 0.0155 - val_loss: 0.0937 - val_mean_squared_error: 0.0937
# Epoch 2/100
# 4/4 [==============================] - 0s 52ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
# Epoch 3/100
# 4/4 [==============================] - 0s 52ms/step - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 4/100
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0176 - val_mean_squared_error: 0.0176
# Epoch 5/100
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0250 - val_mean_squared_error: 0.0250
# Epoch 6/100
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0150 - val_mean_squared_error: 0.0150
# Epoch 7/100
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 8/100
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 9/100
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 10/100
# 4/4 [==============================] - 0s 62ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 11/100
# 4/4 [==============================] - 0s 49ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 12/100
# 4/4 [==============================] - 0s 50ms/step - loss: 9.2700e-04 - mean_squared_error: 9.2700e-04 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 13/100
# 4/4 [==============================] - 0s 45ms/step - loss: 8.6419e-04 - mean_squared_error: 8.6419e-04 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 14/100
# 4/4 [==============================] - 0s 49ms/step - loss: 9.3317e-04 - mean_squared_error: 9.3317e-04 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 15/100
# 4/4 [==============================] - 0s 51ms/step - loss: 8.5587e-04 - mean_squared_error: 8.5587e-04 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 16/100
# 4/4 [==============================] - 0s 54ms/step - loss: 9.7077e-04 - mean_squared_error: 9.7077e-04 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 17/100
# 4/4 [==============================] - 0s 41ms/step - loss: 8.9057e-04 - mean_squared_error: 8.9057e-04 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 18/100
# 4/4 [==============================] - 0s 42ms/step - loss: 7.4095e-04 - mean_squared_error: 7.4095e-04 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 19/100
# 4/4 [==============================] - 0s 56ms/step - loss: 7.9817e-04 - mean_squared_error: 7.9817e-04 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 20/100
# 4/4 [==============================] - 0s 71ms/step - loss: 8.3208e-04 - mean_squared_error: 8.3208e-04 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 21/100
# 4/4 [==============================] - 0s 48ms/step - loss: 8.9987e-04 - mean_squared_error: 8.9987e-04 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 22/100
# 4/4 [==============================] - 0s 37ms/step - loss: 7.8438e-04 - mean_squared_error: 7.8438e-04 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 23/100
# 4/4 [==============================] - 0s 62ms/step - loss: 7.6378e-04 - mean_squared_error: 7.6378e-04 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 24/100
# 4/4 [==============================] - 0s 69ms/step - loss: 7.7053e-04 - mean_squared_error: 7.7053e-04 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 25/100
# 4/4 [==============================] - 0s 42ms/step - loss: 7.5167e-04 - mean_squared_error: 7.5167e-04 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 25: early stopping
# 12/12 [==============================] - 0s 6ms/step
# Epoch 1/100
# 4/4 [==============================] - 4s 95ms/step - loss: 0.0356 - mean_squared_error: 0.0356 - val_loss: 0.1402 - val_mean_squared_error: 0.1402
# Epoch 2/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0089 - val_mean_squared_error: 0.0089
# Epoch 3/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 4/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 5/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0234 - val_mean_squared_error: 0.0234
# Epoch 6/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0231 - val_mean_squared_error: 0.0231
# Epoch 7/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0107 - val_mean_squared_error: 0.0107
# Epoch 8/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 9/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0070 - val_mean_squared_error: 0.0070
# Epoch 10/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0080 - val_mean_squared_error: 0.0080
# Epoch 11/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 12/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 13/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 13: early stopping
# 12/12 [==============================] - 0s 3ms/step
# Epoch 1/100
# 4/4 [==============================] - 1s 90ms/step - loss: 0.0541 - mean_squared_error: 0.0541 - val_loss: 0.3855 - val_mean_squared_error: 0.3855
# Epoch 2/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0274 - mean_squared_error: 0.0274 - val_loss: 0.2342 - val_mean_squared_error: 0.2342
# Epoch 3/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0155 - mean_squared_error: 0.0155 - val_loss: 0.1334 - val_mean_squared_error: 0.1334
# Epoch 4/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0559 - val_mean_squared_error: 0.0559
# Epoch 5/100
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0164 - val_mean_squared_error: 0.0164
# Epoch 6/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0084 - val_mean_squared_error: 0.0084
# Epoch 7/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0133 - val_mean_squared_error: 0.0133
# Epoch 8/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0173 - val_mean_squared_error: 0.0173
# Epoch 9/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0103 - val_mean_squared_error: 0.0103
# Epoch 10/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 11/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 12/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 13/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 14/100
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 15/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 16/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 17/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 18/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 19/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 20/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 21/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 21: early stopping
# 12/12 [==============================] - 0s 4ms/step

# %% [markdown]
# # Loss Function

# %%
# Plot the loss function

def loss(history, company):
    """
    Plot the loss function

    Parameters
    ----------
    history: Keras callbacks History

    company: str
      Company name.

    Returns
    -------
    None
    """

    plt.style.use('ggplot')
    plt.plot(history.history['loss'], label="loss")
    plt.plot(history.history['val_loss'], label="val_loss")

    plt.legend(fontsize=10)
    plt.title(f'Loss of {company}', fontsize=15)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.grid(alpha=0.5)

    plt.show()


stock_list = {'Apple': history_aapl, 'Amazon': history_amzn, 'Google': history_googl, 'Meta': history_meta, 'Microsoft': history_msft}

for company, history in stock_list.items():
    print(loss(history, company),'\n')
# Out:
# None
# None
# None
# None
# None

# %% [markdown]
# # RMSE

# %%
# Measure the prediction by RMSE metric 

print(f'Apple RMSE: {metrics.mean_squared_error(y_test_aapl, y_pred_aapl, squared=False)}')
print(f'Amazon RMSE: {metrics.mean_squared_error(y_test_amzn, y_pred_amzn, squared=False)}')
print(f'Google RMSE: {metrics.mean_squared_error(y_test_googl, y_pred_googl, squared=False)}')
print(f'Meta RMSE: {metrics.mean_squared_error(y_test_meta, y_pred_meta, squared=False)}')
print(f'Microsoft RMSE: {metrics.mean_squared_error(y_test_msft, y_pred_msft, squared=False)}')
# Out:
# Apple RMSE: 0.04788201087666607
# Amazon RMSE: 0.061504675838948725
# Google RMSE: 0.04801425437123821
# Meta RMSE: 0.07955221055198744
# Microsoft RMSE: 0.04706768438228617

# %% [markdown]
# # Denormalization

# %%
# As the predicted stock prices are in normalized formant, denormalization them to the true price format is required

def denormalize(orignial_data, normalized_data):
    """
    Denormalize the predicted stock prices.
  
    Parameters
    ----------
    orignial_data: Pandas Series
      Original input data.

    normalized_data: Numpy array
      Array to denormalized.
   
    Returns
    -------
    Numpy array
      Denormalized data.
    """

    # Reshape the dimension to only one column
    orignial_data = orignial_data.values.reshape(-1,1)
    normalized_data = normalized_data.reshape(-1,1)

    # Instantiate a MinMaxScaler object
    scaler = MinMaxScaler()   
    scaler.fit_transform(orignial_data)
    
    # Denormalize to the original data format
    denormalized_data = scaler.inverse_transform(normalized_data)

    return denormalized_data
   

# Apple
denormalized_pred_aapl = denormalize(aapl_input, y_pred_aapl) 
denormalized_y_test_aapl = denormalize(aapl_input, y_test_aapl)

# Amazon 
denormalized_pred_amzn = denormalize(amzn_input, y_pred_amzn) 
denormalized_y_test_amzn = denormalize(amzn_input, y_test_amzn)

# Google
denormalized_pred_googl = denormalize(googl_input, y_pred_googl) 
denormalized_y_test_googl = denormalize(googl_input, y_test_googl)

# Meta
denormalized_pred_meta = denormalize(meta_input, y_pred_meta) 
denormalized_y_test_meta = denormalize(meta_input, y_test_meta)

# Microsoft
denormalized_pred_msft = denormalize(msft_input, y_pred_msft) 
denormalized_y_test_msft = denormalize(msft_input, y_test_msft)

# %% [markdown]
# # Real Prices vs. Predicted Prices

# %%
# Demonstration of the Real Price vs. Predicted Price

comparision_aapl = pd.DataFrame({'Real Price': denormalized_y_test_aapl.flatten(), 
                                 'Predicted Price': denormalized_pred_aapl.flatten()}, index=df_AAPL[890:].index)
comparision_amzn = pd.DataFrame({'Real Price': denormalized_y_test_amzn.flatten(), 
                                 'Predicted Price': denormalized_pred_amzn.flatten()}, index=df_AMZN[890:].index)
comparision_googl = pd.DataFrame({'Real Price': denormalized_y_test_googl.flatten(), 
                                  'Predicted Price': denormalized_pred_googl.flatten()}, index=df_GOOGL[890:].index)
comparision_meta = pd.DataFrame({'Real Price': denormalized_y_test_meta.flatten(), 
                                 'Predicted Price': denormalized_pred_meta.flatten()}, index=df_META[890:].index)
comparision_msft = pd.DataFrame({'Real Price': denormalized_y_test_msft.flatten(), 
                                 'Predicted Price': denormalized_pred_msft.flatten()}, index=df_MSFT[890:].index)


print(f'Apple: \n {comparision_aapl.head(10)} \n\n')
print(f'Amazon: \n {comparision_amzn.head(10)} \n\n')
print(f'Google: \n {comparision_googl.head(10)} \n\n')
print(f'Meta: \n {comparision_meta.head(10)} \n\n')
print(f'Microsoft: \n {comparision_msft.head(10)} \n\n')
# Out:
# Apple:
#              Real Price  Predicted Price
# Date
# 2020-07-17     94.8499        91.797287
# 2020-07-20     96.8488        91.850563
# 2020-07-21     95.5121        92.333885
# 2020-07-22     95.7804        92.525681
# 2020-07-23     91.4208        92.757118
# 2020-07-24     91.1944        92.824738
# 2020-07-27     93.3557        92.789780
# 2020-07-28     91.8221        92.820587
# 2020-07-29     93.5822        92.426476
# 2020-07-30     94.7145        92.155632
#
#
# Amazon:
#              Real Price  Predicted Price
# Date
# 2020-07-17    148.0985       148.721466
# 2020-07-20    159.8420       148.779343
# 2020-07-21    156.9145       148.154953
# 2020-07-22    154.9955       147.540421
# 2020-07-23    149.3275       147.476852
# 2020-07-24    150.4455       147.587967
# 2020-07-27    152.7605       147.998444
# 2020-07-28    150.0165       147.959366
# 2020-07-29    151.6765       147.601776
# 2020-07-30    152.5940       147.235962
#
#
# Google:
#              Real Price  Predicted Price
# Date
# 2020-07-17     75.8425        74.637032
# 2020-07-20     78.1920        74.590141
# 2020-07-21     77.7960        74.771904
# 2020-07-22     78.2425        75.071136
# 2020-07-23     75.8375        75.507706
# 2020-07-24     75.4105        75.785873
# 2020-07-27     76.4715        75.889801
# 2020-07-28     75.1825        75.895226
# 2020-07-29     76.1755        75.830238
# 2020-07-30     76.9185        75.624939
#
#
# Meta:
#              Real Price  Predicted Price
# Date
# 2020-07-17      242.03       232.010696
# 2020-07-20      245.42       231.855576
# 2020-07-21      241.75       231.793045
# 2020-07-22      239.87       231.663055
# 2020-07-23      232.60       231.536530
# 2020-07-24      230.71       231.545700
# 2020-07-27      233.50       231.326111
# 2020-07-28      230.12       231.192505
# 2020-07-29      233.29       230.206284
# 2020-07-30      234.50       229.045135
#
#
# Microsoft:
#              Real Price  Predicted Price
# Date
# 2020-07-17    198.3259       202.265442
# 2020-07-20    206.8502       202.063995
# 2020-07-21    204.0642       201.496933
# 2020-07-22    206.9968       200.452209
# 2020-07-23    197.9936       199.499619
# 2020-07-24    196.7814       199.406113
# 2020-07-27    199.2741       199.380630
# 2020-07-28    197.4852       199.377335
# 2020-07-29    199.4794       199.213562
# 2020-07-30    199.3230       198.835159

# %% [markdown]
# # Stock Prices Chart

# %%
# Visualize the predicted results

def result_plot(real, predicted, train, company, model):   
    """
    Plot the results in the line chart.

    Parameters
    ----------
    real: Pandas Series
      Real price data.
    predicted:Pandas Series
      Predicted price data.
    train: Pandas Series
      Training data.
    company: str
      Company name.
    model: str
      Model name.

    Returns
    -------
    None
    """

    plt.plot(real, label='Real Price')
    plt.plot(predicted, label='Predicted Price')
    plt.plot(train, label='Training')

    plt.legend(fontsize=10)
    plt.title(f'{company}\'s Stock Prices ({model})')
    plt.xlabel('Date')
    plt.ylabel('Prices ($)')
    plt.show()


print(result_plot(comparision_aapl['Real Price'], comparision_aapl['Predicted Price'], aapl_input[:890], 'Apple', 'CNN'))   
print(result_plot(comparision_amzn['Real Price'], comparision_amzn['Predicted Price'], amzn_input[:890], 'Amazon', 'CNN'))   
print(result_plot(comparision_googl['Real Price'], comparision_googl['Predicted Price'], googl_input[:890], 'Google', 'CNN')) 
print(result_plot(comparision_meta['Real Price'], comparision_meta['Predicted Price'], meta_input[:890], 'Meta', 'CNN')) 
print(result_plot(comparision_msft['Real Price'], comparision_msft['Predicted Price'], msft_input[:890], 'Microsoft', 'CNN'))
# Out:
# None
# None
# None
# None
# None
